# %% [markdown]
# # Assignment 1 (Data Exploration)

# %% [markdown]
# ### Iris Dataset Exploration:

# %% [markdown]
# #### Three flower types (classes):
#     . Setosa
#     . Virginica
#     . Versicolour
# #### Four (non-class) attributes:
#     . Sepal width and length
#     . Petal width and length
# #### Iris dicationary :
#     . 150 elements with 4 attributes for each element
#     . 50 elemnets for each class by order

# %% [markdown]
# #### Import modules :

# %%
# import modules
from sklearn.datasets import load_iris
from mpl_toolkits.mplot3d import Axes3D
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %% [markdown]
# #### load dataset from :

# %%
# print the iris data
iris = load_iris()
x = iris.data
y = iris.target
print (iris.target_names)

# %% [markdown]
# #### Calculate the Cosine Similarity:
# The Cosine similarity is a measure of similarity between two non-zero vectors of an inner product space that
# measures the cosine of the angle between them:
#                         (X, Y ) = < X, Y > /(||X|| ∗ ||Y||)

# %%
iris_cosine_similarity = cosine_similarity(x,x)
# visualize the resultant similarity matrix
im = plt.imshow(iris_cosine_similarity, cmap='RdBu_r') 
plt.colorbar(im, orientation='horizontal')
plt.show()

# %% [markdown]
# ### Plot the X data for each class alone:

# %%
# first class data
irst_df = pd.DataFrame(data = x[:50])
first_df.plot()
first_df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd7182298d0>,
# ...
#       dtype=object)

# %%
# second class data
second_df = pd.DataFrame(data = x[50:100])
second_df.plot()
second_df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd718011898>,
# ...
#       dtype=object)

# %%
# third class data
third_df = pd.DataFrame(data = x[50:100])
third_df.plot()
third_df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd718286518>,
# ...
#       dtype=object)

# %% [markdown]
# #### Plot the X data for each class alone:
# Here we plot each pair of attributes together of the each class.
# the dioginal is histogram as it's the plot of an attribute with itself.
# #### First calss (setosa) :

# %%
sns.set(style="ticks")
df = sns.load_dataset("iris")
setosa_df = df[df['species'] == 'setosa']
sns.pairplot(setosa_df)

# %% [markdown]
# #### Second calss (versicolor) :

# %%
versicolor_df = df[df['species'] == 'versicolor']
sns.pairplot(versicolor_df)

# %% [markdown]
# #### Third calss (virginica) :

# %%
virginica_df = df[df['species'] == 'virginica']
sns.pairplot(virginica_df)

# %% [markdown]
# ### Plot the histogram for each class :
# Here we plot the histogram for each attribute (sepal length, sepal width, petal length, petal width),
# and each class with different color.

# %%
fig, axes = plt.subplots(nrows= 2, ncols=2)
colors= ['blue', 'red', 'green']
for i, ax in enumerate(axes.flat):
    for label, color in zip(range(len(iris.target_names)), colors):
        ax.hist(x[iris.target==label, i], label=             
                            iris.target_names[label], color=color)
        ax.set_xlabel(iris.feature_names[i])  
        ax.legend(loc='upper right')
plt.show()

# %% [markdown]
# ### scatter plot to plot every 2 attributes together:

# %%
sns.pairplot(df, hue="species")

# %% [markdown]
# ### Use 3D scatter plot to plot every 3 attributes together:

# %% [markdown]
# #### Here we plot sepal length, sepal width and petal lenght as scatter plot

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter([x[:, 0]], [x[:, 1]], [x[:, 2]], c = 'b', marker='o')
ax.set_title(iris.feature_names[0] + ", " + iris.feature_names[1] + ", " + iris.feature_names[2])
ax.set_xlabel(iris.feature_names[0])
ax.set_ylabel(iris.feature_names[1])
ax.set_zlabel(iris.feature_names[2])
plt.show()

# %% [markdown]
# #### Here we plot sepal length, sepal width and petal width as scatter plot

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter([x[:, 0]], [x[:, 1]], [x[:, 3]], c = 'r', marker='o')
ax.set_title(iris.feature_names[0] + ", " + iris.feature_names[1] + ", " + iris.feature_names[3])
ax.set_xlabel(iris.feature_names[0])
ax.set_ylabel(iris.feature_names[1])
ax.set_zlabel(iris.feature_names[3])
plt.show()

# %% [markdown]
# #### Here we plot peta width, sepal width and petal lenght as scatter plot

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter([x[:, 3]], [x[:, 1]], [x[:, 2]], c = 'b', marker='o')
ax.set_title(iris.feature_names[3] + ", " + iris.feature_names[1] + ", " + iris.feature_names[2])
ax.set_xlabel(iris.feature_names[3])
ax.set_ylabel(iris.feature_names[1])
ax.set_zlabel(iris.feature_names[2])
plt.show()

# %% [markdown]
# #### Here we plot sepal length, petal width and petal lenght as scatter plot

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter([x[:, 0]], [x[:, 3]], [x[:, 2]], c = 'g', marker='o')
ax.set_title(iris.feature_names[0] + ", " + iris.feature_names[3] + ", " + iris.feature_names[2])
ax.set_xlabel(iris.feature_names[0])
ax.set_ylabel(iris.feature_names[3])
ax.set_zlabel(iris.feature_names[2])
plt.show()
